# %% [markdown]
# # Testing Fresh Install of PyGMT
# Created and tested by A. Newman on 9/23/2022

# %%
import pygmt
pygmt.show_versions()

fig=pygmt.Figure()
fig.coast(region='g',frame=True, shorelines=1)

fig.show()
# Out:
# PyGMT information:
#   version: v0.7.0
# System information:
#   python: 3.9.13 | packaged by conda-forge | (main, May 27 2022, 17:01:00)  [Clang 13.0.1 ]
#   executable: /Users/anewman/opt/anaconda3/envs/Maps/bin/python
#   machine: macOS-12.1-x86_64-i386-64bit
# Dependency information:
#   numpy: 1.23.2
#   pandas: 1.4.3
#   xarray: 2022.6.0
#   netCDF4: 1.6.0
#   packaging: 21.3
#   geopandas: None
#   ghostscript: 9.54.0
#   gmt: 6.4.0
# GMT library information:
#   binary dir: /Users/anewman/opt/anaconda3/envs/Maps/bin
#   cores: 16
#   grid layout: rows
#   library path: /opt/local/lib/gmt6/lib/libgmt.dylib
#   padding: 2
#   plugin dir: /opt/local/lib/gmt6/lib/gmt/plugins
#   share dir: /opt/local/lib/gmt6/share/gmt
#   version: 6.3.0

# %% [markdown]
# as long as a map shows up, you're good to proceed.
