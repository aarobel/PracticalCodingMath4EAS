# %% [markdown]
# # Python Plotting

# %% [markdown]
# A lot of the basic plotting in Python is done through a package called matplotlib. It is desgined to resemble the plotting functionality and syntax of MATLAB, so many of the functions reviewed below are very similar to the MATLAB tutorial

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
b2 = np.arange(2,8,0.5)
b3 = np.linspace(0.4,8.2,10)

# %%
f1=b2**2
plt.plot(b2,f1)

# %%
plt.plot(b2, b2**2, 'o', color='green',label = "line 1")
# plotting the line 2 points 
plt.plot(b2, b2**3, 'o', color='red',label = "line 2")
plt.xlabel('x - axis',fontsize=18)
# Set the y axis label of the current axis.
plt.ylabel('y - axis',fontsize=18)
# Set a title of the current axes.
plt.title('Two or more lines on same plot with suitable legends ')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
[B2,B3] = np.meshgrid(b2,b3)
F3 = np.sin(B2) + np.exp(-(B3-4)**2)
plt.contour(B2,B3,F3)
plt.colorbar          
plt.xlabel('B2',fontsize=20)
plt.ylabel('B3',fontsize=20)
plt.title('F3(B2,B3)',fontsize=20)
# Out:
# Text(0.5, 1.0, 'F3(B2,B3)')

# %%
plt.contourf(B2,B3,F3)
plt.colorbar         
plt.xlabel('B2',fontsize=20)
plt.ylabel('B3',fontsize=20)
plt.title('F3(B2,B3)',fontsize=20)
plt.colorbar()

# %%
plt.pcolor(B2,B3,F3)
plt.colorbar         
plt.xlabel('B2',fontsize=20)
plt.ylabel('B3',fontsize=20)
plt.title('F3(B2,B3)',fontsize=20)
plt.colorbar()
#default colormap in matplotlib is perceptually uniform "viridis" - is seen and interpreted the same regardless of color blindness
# Out:
# /var/folders/c_/227frt1j43jbnz_2d1q8hv640000gr/T/ipykernel_43322/3214372479.py:1: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(B2,B3,F3)

# %%
plt.pcolor(B2,B3,F3,cmap='Greys')
plt.colorbar         
plt.xlabel('B2',fontsize=20)
plt.ylabel('B3',fontsize=20)
plt.title('F3(B2,B3)',fontsize=20)
plt.colorbar()
# Out:
# /var/folders/c_/227frt1j43jbnz_2d1q8hv640000gr/T/ipykernel_43322/1725882090.py:1: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(B2,B3,F3,cmap='Greys')

# %%
plt.pcolor(B2,B3,F3,cmap='seismic',vmin=-1,vmax=1)
plt.colorbar         
plt.xlabel('B2',fontsize=20)
plt.ylabel('B3',fontsize=20)
plt.title('F3(B2,B3)',fontsize=20)
plt.colorbar()
# Out:
# /var/folders/c_/227frt1j43jbnz_2d1q8hv640000gr/T/ipykernel_43322/2336987859.py:1: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(B2,B3,F3,cmap='seismic',vmin=-1,vmax=1)

# %%
plt.pcolor(B2,B3,F3,cmap='hsv')
plt.colorbar         
plt.xlabel('B2',fontsize=20)
plt.ylabel('B3',fontsize=20)
plt.title('F3(B2,B3)',fontsize=20)
plt.colorbar()
# Out:
# /var/folders/c_/227frt1j43jbnz_2d1q8hv640000gr/T/ipykernel_43322/3745469243.py:1: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(B2,B3,F3,cmap='hsv')

# %%
import matplotlib.colors as colors
F4 = np.exp(3*F3)
plt.pcolor(B2,B3,F4,cmap='Greys',norm=colors.LogNorm(vmin=F4.min(), vmax=F4.max()))
plt.colorbar         
plt.xlabel('B2',fontsize=20)
plt.ylabel('B3',fontsize=20)
plt.title('F3(B2,B3)',fontsize=20)
plt.colorbar()
# Out:
# /var/folders/c_/227frt1j43jbnz_2d1q8hv640000gr/T/ipykernel_43322/3951413965.py:3: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(B2,B3,F4,cmap='Greys',norm=colors.LogNorm(vmin=F4.min(), vmax=F4.max()))

# %%
from mpl_toolkits import mplot3d
ax = plt.axes(projection='3d')
ax.plot_surface(B2,B3,F3, rstride=1, cstride=1,cmap='viridis', edgecolor='none')
ax.set_title('surface');
plt.colorbar         
plt.xlabel('B2',fontsize=20)
plt.ylabel('B3',fontsize=20)
plt.title('F3(B2,B3)',fontsize=20)
# Out:
# Text(0.5, 0.92, 'F3(B2,B3)')

# %%
X = 0.3*np.random.randn(10,12) + F3

# %%
n, bins, patches = plt.hist(X.flatten(), bins=10)

# %%
plt.plot((bins[0:10]+bins[1:11])/2,n,color='blue',linewidth=3)
plt.xlabel('X values',fontsize=20)
plt.ylabel('frequency',fontsize=20)
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.boxplot(X[:,7])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7f119cbb80>,
#   <matplotlib.lines.Line2D at 0x7f7f119cbf10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f7f119dc2e0>,
#   <matplotlib.lines.Line2D at 0x7f7f119dc670>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7f119cb7f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7f119dca00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7f119dcd90>],
#  'means': []}

# %%
plt.boxplot(X, positions=b2)
plt.xlabel('b2',fontsize=20)
plt.ylabel('X',fontsize=20)
# Out:
# Text(0, 0.5, 'X')

# %%
f, axs = plt.subplots(1,2, figsize=(20,8))

plt.subplot(1,2,1)
plt.plot(b2, b2**2, 'o', color='green',label = "line 1")

plt.subplot(1,2,2)
plt.pcolor(B2,B3,F4,cmap='Greys',norm=colors.LogNorm(vmin=F4.min(), vmax=F4.max()))
plt.colorbar         
plt.xlabel('B2',fontsize=20)
plt.ylabel('B3',fontsize=20)
plt.title('F3(B2,B3)',fontsize=20)
plt.colorbar()
# Out:
# /var/folders/c_/227frt1j43jbnz_2d1q8hv640000gr/T/ipykernel_43322/2408272939.py:7: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(B2,B3,F4,cmap='Greys',norm=colors.LogNorm(vmin=F4.min(), vmax=F4.max()))
